# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
import autofocus_tools_loci.autofocus_tools as af
from skimage import io
import matplotlib.pyplot as plt
test_image = io.imread(r'test_data/Zstack_HistopathologySlide_CAMM_1_MMStack_crop0.ome.tif')
test_image = test_image[:,:,:,0]*.3 + test_image[:,:,:,1]*.59 + test_image[:,:,:,2]*.11

# %%
N, H, W = test_image.shape

# %% [markdown]
# ### Threshold Absolute Gradient

# %%
threshold_value = 7
z_scores = []
for z_image in test_image:
    z_scores.append(af.threshold_absolute_gradient(z_image, threshold_value))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Squared Gradient

# %%
threshold_value = 0
z_scores = []
for z_image in test_image:
    z_scores.append(af.squared_gradient(z_image, threshold_value))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Brenner Gradient

# %%
threshold_value = 0
z_scores = []
for z_image in test_image:
    z_scores.append(af.brenner_gradient(z_image, threshold_value))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Tenebaum Gradient

# %%
z_scores = []
for z_image in test_image:
    z_scores.append(af.tenenbaum_gradient(z_image))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Sum of Modified Laplace

# %%
z_scores = []
for z_image in test_image:
    z_scores.append(af.sum_of_modified_laplace(z_image))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Energy Laplace

# %%
z_scores = []
for z_image in test_image:
    z_scores.append(af.energy_laplace(z_image))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Defocused Variance

# %%
z_scores = []
for z_image in test_image:
    z_scores.append(af.defocused_variance(z_image))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Normalized Variance

# %%
z_scores = []
for z_image in test_image:
    z_scores.append(af.normalized_variance(z_image))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Auto-correlation

# %%
z_scores = []
for z_image in test_image:
    z_scores.append(af.autocorrelation(z_image))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Standard Deviation Based Correlation

# %%
z_scores = []
for z_image in test_image:
    z_scores.append(af.standard_deviation_based_correlation(z_image))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Histogram Range

# %%
bin_size = 100
z_scores = []
for z_image in test_image:
    z_scores.append(af.range_algorithm(z_image, bin_size))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Threshold Content

# %%
threshold_value = 200
z_scores = []
for z_image in test_image:
    z_scores.append(af.thresholded_content(z_image, threshold_value))

plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Threshold Pixel Count

# %%
threshold_value = 200
z_scores = []
for z_image in test_image:
    z_scores.append(af.thresholded_pixel_count(z_image, threshold_value))
plt.scatter([i for i in range(N)], z_scores)

# %% [markdown]
# ### Image Power

# %%
threshold_value = 200
z_scores = []
for z_image in test_image:
    z_scores.append(af.image_power(z_image, threshold_value))

plt.scatter([i for i in range(N)], z_scores)
